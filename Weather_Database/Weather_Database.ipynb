# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ee9ca9bb2e4f3460ad04856380ad9500

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | walvis bay
# Processing Record 2 of Set 1 | chokurdakh
# Processing Record 3 of Set 1 | fairbanks
# Processing Record 4 of Set 1 | luganville
# Processing Record 5 of Set 1 | ostrovnoy
# Processing Record 6 of Set 1 | upernavik
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | saldanha
# Processing Record 10 of Set 1 | faanui
# Processing Record 11 of Set 1 | victoria
# Processing Record 12 of Set 1 | severnoye
# Processing Record 13 of Set 1 | isangel
# Processing Record 14 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 1 | avarua
# Processing Record 17 of Set 1 | kirkwall
# Processing Record 18 of Set 1 | noyabrsk
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | juegang
# Processing Record 21 of Set 1 | rabo de peixe
# Processing Record 22 of Set 1 | muros
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | broken hill
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | talnakh
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | inhambane
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | san cristobal
# Processing Record 31 of Set 1 | bethel
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | manlleu
# Processing Record 35 of Set 1 | zhenjiang
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | ushuaia
# Processing Record 39 of Set 1 | mentor
# Processing Record 40 of Set 1 | khatanga
# Processing Record 41 of Set 1 | stromness
# Processing Record 42 of Set 1 | port macquarie
# Processing Record 43 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 1 | aklavik
# Processing Record 45 of Set 1 | kapaa
# Processing Record 46 of Set 1 | chuy
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | semey
# Processing Record 49 of Set 1 | sinnamary
# Processing Record 50 of Set 1 | ksenyevka
# City not found. Skipping...
# Processing Record 1 of Set 2 | la libertad
# Processing Record 2 of Set 2 | thompson
# Processing Record 3 of Set 2 | puerto el triunfo
# Processing Record 4 of Set 2 | baykit
# Processing Record 5 of Set 2 | abha
# Processing Record 6 of Set 2 | saint-michel-des-saints
# Processing Record 7 of Set 2 | yellowknife
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | roura
# Processing Record 10 of Set 2 | najran
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | codrington
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 2 | eureka
# Processing Record 17 of Set 2 | yar-sale
# Processing Record 18 of Set 2 | haines junction
# Processing Record 19 of Set 2 | punta arenas
# Processing Record 20 of Set 2 | mutis
# Processing Record 21 of Set 2 | barnstaple
# Processing Record 22 of Set 2 | aksarka
# Processing Record 23 of Set 2 | bluff
# Processing Record 24 of Set 2 | pisco
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | bilma
# Processing Record 27 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 2 | cherskiy
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | tawnat
# City not found. Skipping...
# Processing Record 31 of Set 2 | bathsheba
# Processing Record 32 of Set 2 | san policarpo
# Processing Record 33 of Set 2 | turiacu
# Processing Record 34 of Set 2 | athabasca
# Processing Record 35 of Set 2 | tiksi
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | puerto leguizamo
# Processing Record 38 of Set 2 | marzuq
# Processing Record 39 of Set 2 | swellendam
# Processing Record 40 of Set 2 | fortuna
# Processing Record 41 of Set 2 | leh
# Processing Record 42 of Set 2 | mitu
# Processing Record 43 of Set 2 | ewa beach
# Processing Record 44 of Set 2 | homer
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | behshahr
# Processing Record 48 of Set 2 | tatarbunary
# Processing Record 49 of Set 2 | dwarka
# Processing Record 50 of Set 2 | hirado
# Processing Record 1 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 2 of Set 3 | melfi
# Processing Record 3 of Set 3 | constitucion
# Processing Record 4 of Set 3 | butaritari
# Processing Record 5 of Set 3 | tevaitoa
# Processing Record 6 of Set 3 | alyangula
# Processing Record 7 of Set 3 | karksi-nuia
# Processing Record 8 of Set 3 | bodden town
# Processing Record 9 of Set 3 | touros
# Processing Record 10 of Set 3 | senanga
# Processing Record 11 of Set 3 | kodiak
# Processing Record 12 of Set 3 | keti bandar
# Processing Record 13 of Set 3 | barra patuca
# Processing Record 14 of Set 3 | tasiilaq
# Processing Record 15 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 16 of Set 3 | kloulklubed
# Processing Record 17 of Set 3 | abnub
# Processing Record 18 of Set 3 | new norfolk
# Processing Record 19 of Set 3 | grindavik
# Processing Record 20 of Set 3 | dikson
# Processing Record 21 of Set 3 | severo-kurilsk
# Processing Record 22 of Set 3 | kavieng
# Processing Record 23 of Set 3 | lakatoro
# Processing Record 24 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 3 | clearwater
# Processing Record 26 of Set 3 | college
# Processing Record 27 of Set 3 | auki
# Processing Record 28 of Set 3 | pathein
# Processing Record 29 of Set 3 | iisalmi
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | umm lajj
# Processing Record 32 of Set 3 | geraldton
# Processing Record 33 of Set 3 | marawi
# Processing Record 34 of Set 3 | great falls
# Processing Record 35 of Set 3 | busselton
# Processing Record 36 of Set 3 | zeya
# Processing Record 37 of Set 3 | bukoba
# Processing Record 38 of Set 3 | belyy yar
# Processing Record 39 of Set 3 | dunedin
# Processing Record 40 of Set 3 | sept-iles
# Processing Record 41 of Set 3 | bukavu
# Processing Record 42 of Set 3 | chichli
# Processing Record 43 of Set 3 | east london
# Processing Record 44 of Set 3 | lerwick
# Processing Record 45 of Set 3 | burica
# City not found. Skipping...
# Processing Record 46 of Set 3 | nanortalik
# Processing Record 47 of Set 3 | hobart
# Processing Record 48 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 3 | zaozerne
# Processing Record 50 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 4 | mount isa
# Processing Record 2 of Set 4 | weyburn
# Processing Record 3 of Set 4 | mlonggo
# Processing Record 4 of Set 4 | avera
# Processing Record 5 of Set 4 | kadnikov
# Processing Record 6 of Set 4 | nome
# Processing Record 7 of Set 4 | cabo san lucas
# Processing Record 8 of Set 4 | gushikawa
# Processing Record 9 of Set 4 | saurimo
# Processing Record 10 of Set 4 | longyearbyen
# Processing Record 11 of Set 4 | casper
# Processing Record 12 of Set 4 | mar del plata
# Processing Record 13 of Set 4 | soroti
# Processing Record 14 of Set 4 | torbay
# Processing Record 15 of Set 4 | zvishavane
# Processing Record 16 of Set 4 | yenagoa
# Processing Record 17 of Set 4 | zuwarah
# Processing Record 18 of Set 4 | albany
# Processing Record 19 of Set 4 | dauriya
# Processing Record 20 of Set 4 | paamiut
# Processing Record 21 of Set 4 | tairua
# Processing Record 22 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 23 of Set 4 | alice springs
# Processing Record 24 of Set 4 | vaitape
# Processing Record 25 of Set 4 | zhigansk
# Processing Record 26 of Set 4 | tocantinopolis
# City not found. Skipping...
# Processing Record 27 of Set 4 | sao filipe
# Processing Record 28 of Set 4 | buraydah
# Processing Record 29 of Set 4 | henties bay
# Processing Record 30 of Set 4 | awjilah
# Processing Record 31 of Set 4 | pevek
# Processing Record 32 of Set 4 | san vicente
# Processing Record 33 of Set 4 | zvecka
# Processing Record 34 of Set 4 | olafsvik
# Processing Record 35 of Set 4 | villa carlos paz
# Processing Record 36 of Set 4 | shahrud
# Processing Record 37 of Set 4 | catamarca
# Processing Record 38 of Set 4 | mecca
# Processing Record 39 of Set 4 | lorengau
# Processing Record 40 of Set 4 | provideniya
# Processing Record 41 of Set 4 | veseloyarsk
# Processing Record 42 of Set 4 | klaksvik
# Processing Record 43 of Set 4 | visby
# Processing Record 44 of Set 4 | luena
# Processing Record 45 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 4 | xuddur
# Processing Record 47 of Set 4 | uzunovo
# Processing Record 48 of Set 4 | alofi
# Processing Record 49 of Set 4 | arraial do cabo
# Processing Record 50 of Set 4 | lashio
# Processing Record 1 of Set 5 | kieta
# Processing Record 2 of Set 5 | teguise
# Processing Record 3 of Set 5 | dingle
# Processing Record 4 of Set 5 | kaitangata
# Processing Record 5 of Set 5 | san juan
# Processing Record 6 of Set 5 | la rioja
# Processing Record 7 of Set 5 | xingcheng
# Processing Record 8 of Set 5 | ketchikan
# Processing Record 9 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 5 | namibe
# Processing Record 11 of Set 5 | shingu
# Processing Record 12 of Set 5 | ugoofaaru
# Processing Record 13 of Set 5 | palmer
# Processing Record 14 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 15 of Set 5 | mouzakion
# City not found. Skipping...
# Processing Record 16 of Set 5 | bobo dioulasso
# Processing Record 17 of Set 5 | nasturelu
# Processing Record 18 of Set 5 | vaini
# Processing Record 19 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 5 | asyut
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | marsh harbour
# Processing Record 23 of Set 5 | jardim
# Processing Record 24 of Set 5 | airai
# Processing Record 25 of Set 5 | beihai
# Processing Record 26 of Set 5 | bukowno
# Processing Record 27 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 5 | benjamin aceval
# Processing Record 29 of Set 5 | nikolskoye
# Processing Record 30 of Set 5 | bahia honda
# Processing Record 31 of Set 5 | ossora
# Processing Record 32 of Set 5 | belaya gora
# Processing Record 33 of Set 5 | esperance
# Processing Record 34 of Set 5 | cockburn town
# Processing Record 35 of Set 5 | mmathubudukwane
# Processing Record 36 of Set 5 | nhulunbuy
# Processing Record 37 of Set 5 | ponta do sol
# Processing Record 38 of Set 5 | myra
# Processing Record 39 of Set 5 | pacific grove
# Processing Record 40 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 5 | at-bashi
# Processing Record 42 of Set 5 | muravlenko
# Processing Record 43 of Set 5 | bondo
# Processing Record 44 of Set 5 | goldap
# Processing Record 45 of Set 5 | georgetown
# Processing Record 46 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 47 of Set 5 | tual
# Processing Record 48 of Set 5 | carnarvon
# Processing Record 49 of Set 5 | tiarei
# Processing Record 50 of Set 5 | mananara
# Processing Record 1 of Set 6 | kidal
# Processing Record 2 of Set 6 | madimba
# Processing Record 3 of Set 6 | iqaluit
# Processing Record 4 of Set 6 | mount gambier
# Processing Record 5 of Set 6 | shenjiamen
# Processing Record 6 of Set 6 | eenhana
# Processing Record 7 of Set 6 | westport
# Processing Record 8 of Set 6 | kupang
# Processing Record 9 of Set 6 | sibay
# Processing Record 10 of Set 6 | te anau
# Processing Record 11 of Set 6 | sterling
# Processing Record 12 of Set 6 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 6 | manono
# Processing Record 14 of Set 6 | turayf
# Processing Record 15 of Set 6 | hobyo
# Processing Record 16 of Set 6 | kumano
# Processing Record 17 of Set 6 | nuuk
# Processing Record 18 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 19 of Set 6 | victor harbor
# Processing Record 20 of Set 6 | guerrero negro
# Processing Record 21 of Set 6 | lasa
# Processing Record 22 of Set 6 | clyde river
# Processing Record 23 of Set 6 | hithadhoo
# Processing Record 24 of Set 6 | sitka
# Processing Record 25 of Set 6 | muzhi
# Processing Record 26 of Set 6 | bambous virieux
# Processing Record 27 of Set 6 | saint-francois
# Processing Record 28 of Set 6 | itarema
# Processing Record 29 of Set 6 | kijang
# Processing Record 30 of Set 6 | nago
# Processing Record 31 of Set 6 | luderitz
# Processing Record 32 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 6 | roebourne
# Processing Record 34 of Set 6 | vila velha
# Processing Record 35 of Set 6 | volzhsk
# Processing Record 36 of Set 6 | rohnert park
# Processing Record 37 of Set 6 | niquelandia
# Processing Record 38 of Set 6 | miri
# Processing Record 39 of Set 6 | mitsamiouli
# Processing Record 40 of Set 6 | naryan-mar
# Processing Record 41 of Set 6 | canmore
# Processing Record 42 of Set 6 | kutum
# Processing Record 43 of Set 6 | bonthe
# Processing Record 44 of Set 6 | padang
# Processing Record 45 of Set 6 | dong hoi
# Processing Record 46 of Set 6 | ulaangom
# Processing Record 47 of Set 6 | chimbote
# Processing Record 48 of Set 6 | nabire
# Processing Record 49 of Set 6 | ilulissat
# Processing Record 50 of Set 6 | venado tuerto
# Processing Record 1 of Set 7 | leningradskiy
# Processing Record 2 of Set 7 | talas
# Processing Record 3 of Set 7 | turinsk
# Processing Record 4 of Set 7 | chegdomyn
# Processing Record 5 of Set 7 | kamenka
# Processing Record 6 of Set 7 | gbarnga
# Processing Record 7 of Set 7 | makung
# City not found. Skipping...
# Processing Record 8 of Set 7 | ndjole
# Processing Record 9 of Set 7 | lima
# Processing Record 10 of Set 7 | lompoc
# Processing Record 11 of Set 7 | norman wells
# Processing Record 12 of Set 7 | husavik
# Processing Record 13 of Set 7 | otjiwarongo
# Processing Record 14 of Set 7 | katsuura
# Processing Record 15 of Set 7 | verkh-usugli
# Processing Record 16 of Set 7 | nalut
# Processing Record 17 of Set 7 | san lawrenz
# Processing Record 18 of Set 7 | adre
# Processing Record 19 of Set 7 | cedar city
# Processing Record 20 of Set 7 | plettenberg bay
# Processing Record 21 of Set 7 | rafai
# Processing Record 22 of Set 7 | muncar
# Processing Record 23 of Set 7 | lagoa
# Processing Record 24 of Set 7 | la plata
# Processing Record 25 of Set 7 | bratsk
# Processing Record 26 of Set 7 | kamra
# Processing Record 27 of Set 7 | zhangjiakou
# Processing Record 28 of Set 7 | port elizabeth
# Processing Record 29 of Set 7 | anisoc
# Processing Record 30 of Set 7 | kaseda
# Processing Record 31 of Set 7 | piacabucu
# Processing Record 32 of Set 7 | sao felix do xingu
# Processing Record 33 of Set 7 | sesvete
# Processing Record 34 of Set 7 | waynesville
# Processing Record 35 of Set 7 | kalmunai
# Processing Record 36 of Set 7 | port-gentil
# Processing Record 37 of Set 7 | halifax
# Processing Record 38 of Set 7 | taoudenni
# Processing Record 39 of Set 7 | fare
# Processing Record 40 of Set 7 | atotonilco el alto
# Processing Record 41 of Set 7 | suntar
# Processing Record 42 of Set 7 | karakol
# Processing Record 43 of Set 7 | moyamba
# Processing Record 44 of Set 7 | daru
# Processing Record 45 of Set 7 | sola
# Processing Record 46 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 7 | berbera
# Processing Record 48 of Set 7 | shirokiy
# Processing Record 49 of Set 7 | changji
# Processing Record 50 of Set 7 | camacha
# Processing Record 1 of Set 8 | sibu
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | araceli
# Processing Record 4 of Set 8 | kribi
# Processing Record 5 of Set 8 | yamada
# Processing Record 6 of Set 8 | severnyy
# Processing Record 7 of Set 8 | salinopolis
# Processing Record 8 of Set 8 | faya
# Processing Record 9 of Set 8 | goderich
# Processing Record 10 of Set 8 | toora-khem
# Processing Record 11 of Set 8 | hovd
# Processing Record 12 of Set 8 | vysokogornyy
# Processing Record 13 of Set 8 | novikovo
# Processing Record 14 of Set 8 | coihaique
# Processing Record 15 of Set 8 | saint-philippe
# Processing Record 16 of Set 8 | soyo
# Processing Record 17 of Set 8 | sao jose da coroa grande
# Processing Record 18 of Set 8 | sabang
# Processing Record 19 of Set 8 | yerbogachen
# Processing Record 20 of Set 8 | hirara
# Processing Record 21 of Set 8 | tarko-sale
# Processing Record 22 of Set 8 | saint-joseph
# Processing Record 23 of Set 8 | ribeira grande
# Processing Record 24 of Set 8 | uyuni
# Processing Record 25 of Set 8 | juneau
# Processing Record 26 of Set 8 | djambala
# Processing Record 27 of Set 8 | nara
# Processing Record 28 of Set 8 | saint-pierre
# Processing Record 29 of Set 8 | concepcion del oro
# Processing Record 30 of Set 8 | port hawkesbury
# Processing Record 31 of Set 8 | hoa binh
# Processing Record 32 of Set 8 | paciran
# Processing Record 33 of Set 8 | winslow
# Processing Record 34 of Set 8 | betare oya
# Processing Record 35 of Set 8 | meulaboh
# Processing Record 36 of Set 8 | aykino
# Processing Record 37 of Set 8 | brae
# Processing Record 38 of Set 8 | ipixuna
# Processing Record 39 of Set 8 | kralendijk
# Processing Record 40 of Set 8 | formello
# Processing Record 41 of Set 8 | half moon bay
# Processing Record 42 of Set 8 | araouane
# Processing Record 43 of Set 8 | kembe
# Processing Record 44 of Set 8 | darab
# Processing Record 45 of Set 8 | skelleftea
# Processing Record 46 of Set 8 | bengkulu
# Processing Record 47 of Set 8 | key west
# Processing Record 48 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 49 of Set 8 | athens
# Processing Record 50 of Set 8 | garcia
# Processing Record 1 of Set 9 | charters towers
# Processing Record 2 of Set 9 | goya
# Processing Record 3 of Set 9 | poum
# Processing Record 4 of Set 9 | kanye
# Processing Record 5 of Set 9 | praia
# Processing Record 6 of Set 9 | utiroa
# City not found. Skipping...
# Processing Record 7 of Set 9 | tongliao
# Processing Record 8 of Set 9 | vuktyl
# Processing Record 9 of Set 9 | usinsk
# Processing Record 10 of Set 9 | zwedru
# Processing Record 11 of Set 9 | marystown
# Processing Record 12 of Set 9 | maniitsoq
# Processing Record 13 of Set 9 | kirakira
# Processing Record 14 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 9 | tuatapere
# Processing Record 16 of Set 9 | broome
# Processing Record 17 of Set 9 | nianzishan
# Processing Record 18 of Set 9 | waddan
# Processing Record 19 of Set 9 | banjar
# Processing Record 20 of Set 9 | kukushtan
# Processing Record 21 of Set 9 | laguna
# Processing Record 22 of Set 9 | natal
# Processing Record 23 of Set 9 | ambulu
# Processing Record 24 of Set 9 | comodoro rivadavia
# Processing Record 25 of Set 9 | verkhoyansk
# Processing Record 26 of Set 9 | ushtobe
# Processing Record 27 of Set 9 | falmouth
# Processing Record 28 of Set 9 | svetlaya
# Processing Record 29 of Set 9 | cravo norte
# Processing Record 30 of Set 9 | pochutla
# Processing Record 31 of Set 9 | troitskoye
# Processing Record 32 of Set 9 | bandarbeyla
# Processing Record 33 of Set 9 | susanville
# Processing Record 34 of Set 9 | tabou
# Processing Record 35 of Set 9 | santa maria
# Processing Record 36 of Set 9 | kuching
# Processing Record 37 of Set 9 | darnah
# Processing Record 38 of Set 9 | timmins
# Processing Record 39 of Set 9 | grimari
# City not found. Skipping...
# Processing Record 40 of Set 9 | sioux lookout
# Processing Record 41 of Set 9 | borlange
# City not found. Skipping...
# Processing Record 42 of Set 9 | nortelandia
# Processing Record 43 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 9 | dhadar
# Processing Record 45 of Set 9 | methoni
# Processing Record 46 of Set 9 | colesberg
# Processing Record 47 of Set 9 | vardo
# Processing Record 48 of Set 9 | pokhara
# Processing Record 49 of Set 9 | evensk
# Processing Record 50 of Set 9 | shipitsyno
# Processing Record 1 of Set 10 | yulara
# Processing Record 2 of Set 10 | namwala
# Processing Record 3 of Set 10 | san luis
# Processing Record 4 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 10 | kavaratti
# Processing Record 6 of Set 10 | catalao
# Processing Record 7 of Set 10 | port hardy
# Processing Record 8 of Set 10 | bengkalis
# City not found. Skipping...
# Processing Record 9 of Set 10 | balasinor
# City not found. Skipping...
# Processing Record 10 of Set 10 | kununurra
# Processing Record 11 of Set 10 | sibolga
# Processing Record 12 of Set 10 | biak
# Processing Record 13 of Set 10 | yuanping
# Processing Record 14 of Set 10 | jhudo
# Processing Record 15 of Set 10 | morgan city
# Processing Record 16 of Set 10 | ambilobe
# Processing Record 17 of Set 10 | pangnirtung
# Processing Record 18 of Set 10 | deputatskiy
# Processing Record 19 of Set 10 | tiznit
# Processing Record 20 of Set 10 | killybegs
# Processing Record 21 of Set 10 | revelstoke
# Processing Record 22 of Set 10 | guanica
# Processing Record 23 of Set 10 | puerto escondido
# Processing Record 24 of Set 10 | kishcha
# Processing Record 25 of Set 10 | kahului
# Processing Record 26 of Set 10 | tingi
# Processing Record 27 of Set 10 | camocim
# Processing Record 28 of Set 10 | les escoumins
# Processing Record 29 of Set 10 | maragogi
# Processing Record 30 of Set 10 | pitimbu
# Processing Record 31 of Set 10 | el balyana
# City not found. Skipping...
# Processing Record 32 of Set 10 | bumba
# Processing Record 33 of Set 10 | bam
# Processing Record 34 of Set 10 | houma
# Processing Record 35 of Set 10 | toowoomba
# Processing Record 36 of Set 10 | baculin
# Processing Record 37 of Set 10 | port lincoln
# Processing Record 38 of Set 10 | mareeba
# Processing Record 39 of Set 10 | shimoda
# Processing Record 40 of Set 10 | riverton
# Processing Record 41 of Set 10 | tolosa
# Processing Record 42 of Set 10 | arlit
# Processing Record 43 of Set 10 | jauja
# Processing Record 44 of Set 10 | raudeberg
# Processing Record 45 of Set 10 | komsomolskiy
# Processing Record 46 of Set 10 | manakara
# Processing Record 47 of Set 10 | goryachegorsk
# Processing Record 48 of Set 10 | kemijarvi
# Processing Record 49 of Set 10 | soyaux
# Processing Record 50 of Set 10 | babstovo
# Processing Record 1 of Set 11 | cossato
# Processing Record 2 of Set 11 | richmond
# Processing Record 3 of Set 11 | sao joao da barra
# Processing Record 4 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 11 | dalby
# Processing Record 6 of Set 11 | umm ruwabah
# City not found. Skipping...
# Processing Record 7 of Set 11 | nieuw amsterdam
# Processing Record 8 of Set 11 | nurota
# Processing Record 9 of Set 11 | toktogul
# Processing Record 10 of Set 11 | dolores
# Processing Record 11 of Set 11 | ibra
# Processing Record 12 of Set 11 | moses lake
# Processing Record 13 of Set 11 | coffs harbour
# Processing Record 14 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 15 of Set 11 | latung
# Processing Record 16 of Set 11 | aripuana
# Processing Record 17 of Set 11 | souillac
# Processing Record 18 of Set 11 | cidreira
# Processing Record 19 of Set 11 | ahipara
# Processing Record 20 of Set 11 | gat
# Processing Record 21 of Set 11 | the valley
# Processing Record 22 of Set 11 | ronneby
# Processing Record 23 of Set 11 | asau
# Processing Record 24 of Set 11 | itoman
# Processing Record 25 of Set 11 | antalaha
# Processing Record 26 of Set 11 | rongcheng
# Processing Record 27 of Set 11 | turan
# Processing Record 28 of Set 11 | viedma
# Processing Record 29 of Set 11 | lodwar
# Processing Record 30 of Set 11 | san javier
# Processing Record 31 of Set 11 | bezenchuk
# Processing Record 32 of Set 11 | nishihara
# Processing Record 33 of Set 11 | catalina foothills
# Processing Record 34 of Set 11 | rorvik
# Processing Record 35 of Set 11 | zambezi
# Processing Record 36 of Set 11 | katha
# City not found. Skipping...
# Processing Record 37 of Set 11 | gaya
# Processing Record 38 of Set 11 | palasa
# Processing Record 39 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 40 of Set 11 | chupa
# Processing Record 41 of Set 11 | poplar bluff
# Processing Record 42 of Set 11 | kokstad
# Processing Record 43 of Set 11 | kawalu
# Processing Record 44 of Set 11 | seymchan
# Processing Record 45 of Set 11 | koumac
# Processing Record 46 of Set 11 | millau
# Processing Record 47 of Set 11 | bulawayo
# Processing Record 48 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 11 | vao
# Processing Record 50 of Set 11 | aska
# Processing Record 1 of Set 12 | terrace
# Processing Record 2 of Set 12 | ruwi
# Processing Record 3 of Set 12 | tigil
# Processing Record 4 of Set 12 | sur
# Processing Record 5 of Set 12 | ankola
# Processing Record 6 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 12 | bakchar
# Processing Record 8 of Set 12 | praia da vitoria
# Processing Record 9 of Set 12 | khonsa
# Processing Record 10 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 12 | okhotsk
# Processing Record 12 of Set 12 | svetlogorsk
# Processing Record 13 of Set 12 | vega de alatorre
# Processing Record 14 of Set 12 | moerai
# Processing Record 15 of Set 12 | depok
# Processing Record 16 of Set 12 | qaqortoq
# Processing Record 17 of Set 12 | dezful
# Processing Record 18 of Set 12 | thanh hoa
# Processing Record 19 of Set 12 | la ronge
# Processing Record 20 of Set 12 | vershino-shakhtaminskiy
# Processing Record 21 of Set 12 | usogorsk
# Processing Record 22 of Set 12 | san juan de colon
# Processing Record 23 of Set 12 | rapu-rapu
# Processing Record 24 of Set 12 | rincon
# Processing Record 25 of Set 12 | luocheng
# Processing Record 26 of Set 12 | luwuk
# Processing Record 27 of Set 12 | egvekinot
# Processing Record 28 of Set 12 | poya
# Processing Record 29 of Set 12 | kyrylivka
# Processing Record 30 of Set 12 | wrzesnia
# Processing Record 31 of Set 12 | atambua
# Processing Record 32 of Set 12 | batagay-alyta
# Processing Record 33 of Set 12 | iroquois falls
# Processing Record 34 of Set 12 | peleduy
# Processing Record 35 of Set 12 | neiafu
# Processing Record 36 of Set 12 | chapais
# Processing Record 37 of Set 12 | batagay
# Processing Record 38 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 39 of Set 12 | mehamn
# Processing Record 40 of Set 12 | udachnyy
# Processing Record 41 of Set 12 | hambantota
# Processing Record 42 of Set 12 | ghanzi
# Processing Record 43 of Set 12 | namatanai
# Processing Record 44 of Set 12 | margate
# Processing Record 45 of Set 12 | puerto penasco
# Processing Record 46 of Set 12 | ancud
# Processing Record 47 of Set 12 | malaga
# Processing Record 48 of Set 12 | vanimo
# Processing Record 49 of Set 12 | san patricio
# Processing Record 50 of Set 12 | sartana
# Processing Record 1 of Set 13 | hami
# Processing Record 2 of Set 13 | takoradi
# Processing Record 3 of Set 13 | shihezi
# Processing Record 4 of Set 13 | togul
# Processing Record 5 of Set 13 | vostok
# Processing Record 6 of Set 13 | jalu
# Processing Record 7 of Set 13 | cruzeiro
# Processing Record 8 of Set 13 | malatya
# Processing Record 9 of Set 13 | bitung
# Processing Record 10 of Set 13 | karratha
# Processing Record 11 of Set 13 | ouadda
# Processing Record 12 of Set 13 | los alamos
# Processing Record 13 of Set 13 | mezen
# Processing Record 14 of Set 13 | beipiao
# Processing Record 15 of Set 13 | zabaykalsk
# Processing Record 16 of Set 13 | trelew
# Processing Record 17 of Set 13 | tazovskiy
# Processing Record 18 of Set 13 | batatais
# Processing Record 19 of Set 13 | serenje
# Processing Record 20 of Set 13 | aitape
# Processing Record 21 of Set 13 | chatellerault
# Processing Record 22 of Set 13 | coahuayana
# Processing Record 23 of Set 13 | havelock
# Processing Record 24 of Set 13 | almaznyy
# Processing Record 25 of Set 13 | urucui
# Processing Record 26 of Set 13 | artigas
# Processing Record 27 of Set 13 | sorland
# Processing Record 28 of Set 13 | nushki
# Processing Record 29 of Set 13 | coquimbo
# Processing Record 30 of Set 13 | aljezur
# Processing Record 31 of Set 13 | gouyave
# Processing Record 32 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 33 of Set 13 | shache
# Processing Record 34 of Set 13 | mwene-ditu
# Processing Record 35 of Set 13 | bubaque
# Processing Record 36 of Set 13 | kulhudhuffushi
# Processing Record 37 of Set 13 | cooma
# Processing Record 38 of Set 13 | caravelas
# Processing Record 39 of Set 13 | prince rupert
# Processing Record 40 of Set 13 | opuwo
# Processing Record 41 of Set 13 | fairview
# Processing Record 42 of Set 13 | ornskoldsvik
# Processing Record 43 of Set 13 | flinders
# Processing Record 44 of Set 13 | fukue
# Processing Record 45 of Set 13 | kodinar
# Processing Record 46 of Set 13 | santa isabel
# Processing Record 47 of Set 13 | chadan
# Processing Record 48 of Set 13 | yantzaza
# Processing Record 49 of Set 13 | mackay
# Processing Record 50 of Set 13 | sheksna
# Processing Record 1 of Set 14 | phalaborwa
# Processing Record 2 of Set 14 | funadhoo
# Processing Record 3 of Set 14 | aksu
# Processing Record 4 of Set 14 | newport
# Processing Record 5 of Set 14 | rio gallegos
# Processing Record 6 of Set 14 | garden city
# Processing Record 7 of Set 14 | carutapera
# Processing Record 8 of Set 14 | tabas
# Processing Record 9 of Set 14 | malinyi
# Processing Record 10 of Set 14 | winchester
# Processing Record 11 of Set 14 | inuvik
# Processing Record 12 of Set 14 | shakawe
# Processing Record 13 of Set 14 | bowen
# Processing Record 14 of Set 14 | kayerkan
# Processing Record 15 of Set 14 | xining
# Processing Record 16 of Set 14 | bataipora
# Processing Record 17 of Set 14 | goba
# Processing Record 18 of Set 14 | shibarghan
# City not found. Skipping...
# Processing Record 19 of Set 14 | ulaanbaatar
# Processing Record 20 of Set 14 | bachaquero
# Processing Record 21 of Set 14 | carman
# Processing Record 22 of Set 14 | redlands
# Processing Record 23 of Set 14 | port hedland
# Processing Record 24 of Set 14 | dawson creek
# Processing Record 25 of Set 14 | batticaloa
# Processing Record 26 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 14 | sorong
# Processing Record 28 of Set 14 | markova
# Processing Record 29 of Set 14 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 30 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 14 | ajdabiya
# Processing Record 32 of Set 14 | bara
# Processing Record 33 of Set 14 | biskamzha
# Processing Record 34 of Set 14 | ekibastuz
# Processing Record 35 of Set 14 | biu
# Processing Record 36 of Set 14 | saint anthony
# Processing Record 37 of Set 14 | matamoros
# Processing Record 38 of Set 14 | shimanovsk
# Processing Record 39 of Set 14 | kumo
# Processing Record 40 of Set 14 | enterprise
# Processing Record 41 of Set 14 | buchanan
# Processing Record 42 of Set 14 | nova venecia
# Processing Record 43 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 44 of Set 14 | cottage grove
# Processing Record 45 of Set 14 | seoul
# Processing Record 46 of Set 14 | senekal
# Processing Record 47 of Set 14 | gboko
# Processing Record 48 of Set 14 | panacan
# Processing Record 49 of Set 14 | lithgow
# Processing Record 50 of Set 14 | brooks
# Processing Record 1 of Set 15 | los llanos de aridane
# Processing Record 2 of Set 15 | sangmelima
# Processing Record 3 of Set 15 | tefe
# Processing Record 4 of Set 15 | sungaipenuh
# Processing Record 5 of Set 15 | elizabeth city
# Processing Record 6 of Set 15 | shaoyang
# Processing Record 7 of Set 15 | tolga
# Processing Record 8 of Set 15 | matara
# Processing Record 9 of Set 15 | atbasar
# Processing Record 10 of Set 15 | golden
# Processing Record 11 of Set 15 | asuncion mita
# Processing Record 12 of Set 15 | guhagar
# Processing Record 13 of Set 15 | naze
# Processing Record 14 of Set 15 | tezu
# Processing Record 15 of Set 15 | ramanathapuram
# Processing Record 16 of Set 15 | beisfjord
# Processing Record 17 of Set 15 | karachi
# Processing Record 18 of Set 15 | plouzane
# Processing Record 19 of Set 15 | manzhouli
# Processing Record 20 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 15 | oriximina
# Processing Record 22 of Set 15 | colotlan
# Processing Record 23 of Set 15 | safwah
# City not found. Skipping...
# Processing Record 24 of Set 15 | dudinka
# Processing Record 25 of Set 15 | marfino
# Processing Record 26 of Set 15 | la baule-escoublac
# Processing Record 27 of Set 15 | sovetskiy
# Processing Record 28 of Set 15 | esfahan
# Processing Record 29 of Set 15 | meadow lake
# Processing Record 30 of Set 15 | zheleznodorozhnyy
# Processing Record 31 of Set 15 | mizdah
# Processing Record 32 of Set 15 | sidi ali
# Processing Record 33 of Set 15 | port said
# Processing Record 34 of Set 15 | riberalta
# Processing Record 35 of Set 15 | san juan de la maguana
# Processing Record 36 of Set 15 | veraval
# Processing Record 37 of Set 15 | gamba
# Processing Record 38 of Set 15 | acucena
# Processing Record 39 of Set 15 | ngunguru
# Processing Record 40 of Set 15 | mahajanga
# Processing Record 41 of Set 15 | riohacha
# Processing Record 42 of Set 15 | wasilla
# Processing Record 43 of Set 15 | russell
# Processing Record 44 of Set 15 | simpang
# Processing Record 45 of Set 15 | salalah
# Processing Record 46 of Set 15 | candawaga
# City not found. Skipping...
# Processing Record 47 of Set 15 | makakilo city
# Processing Record 48 of Set 15 | skole
# Processing Record 49 of Set 15 | panjwin
# City not found. Skipping...
# Processing Record 50 of Set 15 | boende
# Processing Record 1 of Set 16 | khani
# Processing Record 2 of Set 16 | virginia beach
# Processing Record 3 of Set 16 | huilong
# Processing Record 4 of Set 16 | krasnoselkup
# Processing Record 5 of Set 16 | panaba
# Processing Record 6 of Set 16 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 16 | oktyabrskiy
# Processing Record 8 of Set 16 | hokitika
# Processing Record 9 of Set 16 | shirgaon
# Processing Record 10 of Set 16 | punakha
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Walvis Bay -22.96   14.51     55.99        87           0        5.82
# 1    Chokurdakh  70.63  147.92     34.68        88         100       10.65
# 2     Fairbanks  64.84 -147.72     64.40        68          90        1.50
# 3    Luganville -15.53  167.17     77.00       100          75        7.16
# 4     Ostrovnoy  68.05   39.51     58.14        90          32       16.96
# 5     Upernavik  72.79  -56.15     44.53        84          94        7.31
# 6        Hasaki  35.73  140.83     75.20       100          75        4.70
# 7  Puerto Ayora  -0.74  -90.35     77.00        53          63       17.22
# 8      Saldanha -33.01   17.94     57.20        87          75        8.05
# 9        Faanui -16.48 -151.75     76.64        78          16       19.53
#
#   Country Current Description
# 0      NA           clear sky
# 1      RU     overcast clouds
# 2      US     overcast clouds
# 3      VU       broken clouds
# 4      RU    scattered clouds
# 5      GL     overcast clouds
# 6      JP                mist
# 7      EC       broken clouds
# 8      ZA       broken clouds
# 9      PF          few clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0  Walvis Bay      NA -22.96   14.51     55.99        87           0
# 1  Chokurdakh      RU  70.63  147.92     34.68        88         100
# 2   Fairbanks      US  64.84 -147.72     64.40        68          90
# 3  Luganville      VU -15.53  167.17     77.00       100          75
# 4   Ostrovnoy      RU  68.05   39.51     58.14        90          32
#
#    Wind Speed Current Description
# 0        5.82           clear sky
# 1       10.65     overcast clouds
# 2        1.50     overcast clouds
# 3        7.16       broken clouds
# 4       16.96    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
